# %%
import numpy as np #importar libreria matematica
import plotly.express as px #herramienta de plot
import plotly.graph_objects as go

# %% [markdown]
# # Calculando al Coyote

# %% [markdown]
# > Un cuerpo cuadrado de b=3[m] de masa m=2000[kg] que pivota sobre la esquina (punto O). Suponga que la piedra rueda sin deslizar y que hay una fricción en la rueda con µ=0.3. Calcule :
# - el ángulo al cual el cuerpo pierde contacto con la esquina (punto O) y empieza a caer
# - y ya que estamos también realice un gráfico de la variación de la velocidad angular hasta el mismo ángulo del literal anterior
# - ¿podría pasar lo que pasó en el vídeo?

# %% [markdown]
# # $Resolución:$#
# ![image.png](attachment:55069331-aef4-4851-a7bb-57abb3e17d45.png)!
# ![image.png](attachment:1ecafa9e-2e2b-4fb2-aa44-e0733468596c.png)!

# %%
>Al hacer la suma de las fuerzas en los ejes correspondientes se obtiene lo siguiente:

# %% [markdown]
# >Para el eje x se tiene que:
# $$\Sigma F_{x}=0 $$
# $$-fr*cos(\theta)+N*sen(\theta)=0$$        $$-u*N*cos(\theta)+N*sen(\theta)=0$$
# $$N*(sen(\theta)-u*cos(\theta))=0$$
# > Patra tener que la expresión $$\Sigma F_{x}=0 $$ sea = 0 tenemos 2 posibles valores, por ejemplo el primero seria que se cumpla la siguiente expresión:
# $$N=0$$ o que $$(sen(\theta)-u*cos(\theta))=0$$
# $$sen(\theta)-u*cos(\theta)=0$$
# $$sen(\theta)=u*cos(\theta)$$
# $$\frac{sen(\theta)}{cos(\theta)} = u$$
# $$tan(\theta)=0.3$$
# $$\theta=16.70^°$$

# %% [markdown]
# >Para el eje y se tiene que:
# $$\Sigma F_{y}=0 $$
# $$fr*sen(\theta)+N*cos(\theta)-mg=0$$
# $$u*N*sen(\theta)+N*cos(\theta)=mg$$
# $$N*(cos(\theta)+u*sen(\theta))=mg$$
# $$N=mg/(cos(\theta)+u*sen(\theta))$$
# >con esta expresión se determina la variación de la Fuerza Normal respecto al ángulo (\theta)

# %%
from math import sin
from math import pi
from math import cos
mg= 19.62*1000
th=np.arange (0,pi,1)
vth = np.array(np.deg2rad(th))
vs=(19.62*1000)/(np.cos(th)+0.3*np.sin(th))
fig=px.line(x=th,y=vs,labels={'x':'theta[deg]','y':'Fuerza Normal en KN'},title="Variación de la Normal respecto al ángulo giro")
fig.show()

# %%
import plotly.express as px 
th=np.arange(0,90,0.1) 
vth = np.array(np.deg2rad(th)) 
T2=(5/12)*9.81/3*(1-np.cos(th/180*np.pi))
fig=px.line(x=th,y=w2,labels={'x':'Ángulo de inclinación tetha [rad]','y':'Velocidad angular [rad/s]'},title="Variación de la velocidad angular con respecto al ángulo de giro")
fig.show()
